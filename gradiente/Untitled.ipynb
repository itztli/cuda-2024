# %%
# !pip3 install pytorch
# Out:
# ...
#   Using cached pytorch-1.0.2.tar.gz (689 bytes)
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [6 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-install-6vnjm_mm/pytorch_44a8ed80d6104988aa7fb2ce81310072/setup.py", line 15, in <module>
#           raise Exception(message)
#       Exception: You tried to install "pytorch". The package named for PyTorch is "torch"
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pytorch
#   Running setup.py clean for pytorch
# Failed to build pytorch
# ...
#   Running setup.py install for pytorch ... error
#   error: subprocess-exited-with-error
#
# ...

# %%
# !conda list
# Out:
# # packages in environment at /home/vdelaluz/anaconda3:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main
# _openmp_mutex             5.1                       1_gnu
# aioftp                    0.22.3                   pypi_0    pypi
# aiohttp                   3.9.3                    pypi_0    pypi
# aiosignal                 1.3.1                    pypi_0    pypi
# alabaster                 0.7.12             pyhd3eb1b0_0
# anaconda-client           1.11.2          py310h06a4308_0
# anaconda-navigator        2.4.0           py310h06a4308_0
# anaconda-project          0.11.1          py310h06a4308_0
# anyio                     3.5.0           py310h06a4308_0
# appdirs                   1.4.4              pyhd3eb1b0_0
# argcomplete               3.1.1                    pypi_0    pypi
# argon2-cffi               21.3.0             pyhd3eb1b0_0
# ...

# %%
# !conda activate base
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.
